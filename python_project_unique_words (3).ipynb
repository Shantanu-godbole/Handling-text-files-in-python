# %%
file=open("conv.txt","r")
empty_list=[]
unique_characters=[]
dict={}
sent=[]
new_sent=[]

# %%
for i in file:
    list=i.split(":")
    empty_list.append(list)

# %%
empty_list
# Out:
# [['WILL',
#   ' Iâ€™ve never seen wildlings do a thing like this. Iâ€™ve never seen a thing like this, not ever in my life.\n'],
#  ['\n'],
#  ['WAYMAR ROYCE', ' How close did you get?\n'],
#  ['\n'],
#  ['WILL', ' Close as any man would.\n'],
#  ['\n'],
#  ['GARED', ' We should head back to the wall.\n'],
#  ['\n'],
#  ['ROYCE', ' Do the dead frighten you?\n'],
#  ['\n'],
#  ['GARED',
#   ' Our orders were to track the wildlings. We tracked them. They wonâ€™t trouble us no more.\n'],
#  ['\n'],
#  ['ROYCE',
#   ' You donâ€™t think heâ€™ll ask us how they died? Get back on your horse.\n'],
#  ['\n'],
#  ['WILL',
#   ' Whatever did it to them could do it to us. They even killed the children.\n'],
#  ['\n'],
#  ['ROYCE',
#   ' Itâ€™s a good thing weâ€™re not children. You want to run away south, run away. Of course, they will behead you as a deserter â€¦ If I donâ€™t catch you first. Get back on your horse. I wonâ€™t say it again.\n'],
#  ['\n'],
# ...

# %%
empty_list
# Out:
# [['WILL',
#   ' Iâ€™ve never seen wildlings do a thing like this. Iâ€™ve never seen a thing like this, not ever in my life.\n'],
#  ['\n'],
#  ['WAYMAR ROYCE', ' How close did you get?\n'],
#  ['\n'],
#  ['WILL', ' Close as any man would.\n'],
#  ['\n'],
#  ['GARED', ' We should head back to the wall.\n'],
#  ['\n'],
#  ['ROYCE', ' Do the dead frighten you?\n'],
#  ['\n'],
#  ['GARED',
#   ' Our orders were to track the wildlings. We tracked them. They wonâ€™t trouble us no more.\n'],
#  ['\n'],
#  ['ROYCE',
#   ' You donâ€™t think heâ€™ll ask us how they died? Get back on your horse.\n'],
#  ['\n'],
#  ['WILL',
#   ' Whatever did it to them could do it to us. They even killed the children.\n'],
#  ['\n'],
#  ['ROYCE',
#   ' Itâ€™s a good thing weâ€™re not children. You want to run away south, run away. Of course, they will behead you as a deserter â€¦ If I donâ€™t catch you first. Get back on your horse. I wonâ€™t say it again.\n'],
#  ['\n'],
# ...

# %%
empty_list[1][0]
# Out:
# '\n'

# %% [markdown]
# empty_list

# %%
empty_list
# Out:
# [['WILL',
#   ' Iâ€™ve never seen wildlings do a thing like this. Iâ€™ve never seen a thing like this, not ever in my life.\n'],
#  ['\n'],
#  ['WAYMAR ROYCE', ' How close did you get?\n'],
#  ['\n'],
#  ['WILL', ' Close as any man would.\n'],
#  ['\n'],
#  ['GARED', ' We should head back to the wall.\n'],
#  ['\n'],
#  ['ROYCE', ' Do the dead frighten you?\n'],
#  ['\n'],
#  ['GARED',
#   ' Our orders were to track the wildlings. We tracked them. They wonâ€™t trouble us no more.\n'],
#  ['\n'],
#  ['ROYCE',
#   ' You donâ€™t think heâ€™ll ask us how they died? Get back on your horse.\n'],
#  ['\n'],
#  ['WILL',
#   ' Whatever did it to them could do it to us. They even killed the children.\n'],
#  ['\n'],
#  ['ROYCE',
#   ' Itâ€™s a good thing weâ€™re not children. You want to run away south, run away. Of course, they will behead you as a deserter â€¦ If I donâ€™t catch you first. Get back on your horse. I wonâ€™t say it again.\n'],
#  ['\n'],
# ...

# %%
c=empty_list[0: :2]

# %%
c
# Out:
# [['WILL',
#   ' Iâ€™ve never seen wildlings do a thing like this. Iâ€™ve never seen a thing like this, not ever in my life.\n'],
#  ['WAYMAR ROYCE', ' How close did you get?\n'],
#  ['WILL', ' Close as any man would.\n'],
#  ['GARED', ' We should head back to the wall.\n'],
#  ['ROYCE', ' Do the dead frighten you?\n'],
#  ['GARED',
#   ' Our orders were to track the wildlings. We tracked them. They wonâ€™t trouble us no more.\n'],
#  ['ROYCE',
#   ' You donâ€™t think heâ€™ll ask us how they died? Get back on your horse.\n'],
#  ['WILL',
#   ' Whatever did it to them could do it to us. They even killed the children.\n'],
#  ['ROYCE',
#   ' Itâ€™s a good thing weâ€™re not children. You want to run away south, run away. Of course, they will behead you as a deserter â€¦ If I donâ€™t catch you first. Get back on your horse. I wonâ€™t say it again.\n'],
#  ['ROYCE', ' Your dead men seem to have moved camp.\n'],
#  ['WILL', ' They were here.\n'],
#  ['GARED', ' See where they went.\n'],
# ...

# %%
empty_list
# Out:
# [['WILL',
#   ' Iâ€™ve never seen wildlings do a thing like this. Iâ€™ve never seen a thing like this, not ever in my life.\n'],
#  ['\n'],
#  ['WAYMAR ROYCE', ' How close did you get?\n'],
#  ['\n'],
#  ['WILL', ' Close as any man would.\n'],
#  ['\n'],
#  ['GARED', ' We should head back to the wall.\n'],
#  ['\n'],
#  ['ROYCE', ' Do the dead frighten you?\n'],
#  ['\n'],
#  ['GARED',
#   ' Our orders were to track the wildlings. We tracked them. They wonâ€™t trouble us no more.\n'],
#  ['\n'],
#  ['ROYCE',
#   ' You donâ€™t think heâ€™ll ask us how they died? Get back on your horse.\n'],
#  ['\n'],
#  ['WILL',
#   ' Whatever did it to them could do it to us. They even killed the children.\n'],
#  ['\n'],
#  ['ROYCE',
#   ' Itâ€™s a good thing weâ€™re not children. You want to run away south, run away. Of course, they will behead you as a deserter â€¦ If I donâ€™t catch you first. Get back on your horse. I wonâ€™t say it again.\n'],
#  ['\n'],
# ...

# %%
for k in range(0,len(c)):
    unique_characters.append(c[k][0])

# %%
unique_characters
# Out:
# ['WILL',
#  'WAYMAR ROYCE',
#  'WILL',
#  'GARED',
#  'ROYCE',
#  'GARED',
#  'ROYCE',
#  'WILL',
#  'ROYCE',
#  'ROYCE',
#  'WILL',
#  'GARED',
#  'ROYCE',
#  'JON',
#  'JON',
#  'SEPTA MORDANE',
#  'SANSA',
#  'SEPTA MORDANE',
#  'NED',
#  'JON',
#  'ROBB',
#  'CASSEL',
#  'NED',
#  'CATELYN',
#  'NED',
#  'CASSEL',
#  'NED',
#  'CATELYN',
#  'NED',
#  'ROBB',
#  'NED',
#  'JON',
#  'NED',
#  'JON',
#  'NED',
#  'BRAN',
#  'NED',
#  'BRAN',
#  'NED',
#  'BRAN',
#  'NED',
#  'BRAN',
#  'NED',
#  'JON',
#  'THEON',
#  'NED',
#  'THEON',
#  'NED',
#  'NED',
#  'ROBB',
#  'JON',
#  'JON',
#  'BRAN',
#  'CASSEL',
#  'NED',
#  'THEON',
#  'BRAN',
#  'ROBB',
#  'THEON',
#  'BRAN',
#  'NED',
#  'JON',
#  'NED',
#  'BRAN',
#  'JON',
#  'ROBB',
#  'CERSEI',
#  'JAIME',
#  'CERSEI',
#  'JAIME',
#  'CERSEI',
#  'JAIME',
#  'CATELYN',
#  'NED',
#  'CATELYN',
#  'NED',
#  'CATELYN',
#  'NED',
#  'ROBB',
#  'THEON',
#  'ROBB',
#  'CATELYN',
#  'BRAN',
#  'CATELYN',
#  'BRAN',
#  'CATELYN',
# ...

# %%
final_unique_char=set(unique_characters)

# %%
final_unique_char
# Out:
# {'ARYA',
#  'BRAN',
#  'CASSEL',
#  'CATELYN',
#  'CERSEI',
#  'GARED',
#  'JAIME',
#  'JON',
#  'NED',
#  'ROBB',
#  'ROBERT',
#  'ROYCE',
#  'SANSA',
#  'SEPTA MORDANE',
#  'THEON',
#  'WAYMAR ROYCE',
#  'WILL'}

# %%
final_unique_char
# Out:
# {'ARYA',
#  'BRAN',
#  'CASSEL',
#  'CATELYN',
#  'CERSEI',
#  'GARED',
#  'JAIME',
#  'JON',
#  'NED',
#  'ROBB',
#  'ROBERT',
#  'ROYCE',
#  'SANSA',
#  'SEPTA MORDANE',
#  'THEON',
#  'WAYMAR ROYCE',
#  'WILL'}

# %%
c
# Out:
# [['WILL',
#   ' Iâ€™ve never seen wildlings do a thing like this. Iâ€™ve never seen a thing like this, not ever in my life.\n'],
#  ['WAYMAR ROYCE', ' How close did you get?\n'],
#  ['WILL', ' Close as any man would.\n'],
#  ['GARED', ' We should head back to the wall.\n'],
#  ['ROYCE', ' Do the dead frighten you?\n'],
#  ['GARED',
#   ' Our orders were to track the wildlings. We tracked them. They wonâ€™t trouble us no more.\n'],
#  ['ROYCE',
#   ' You donâ€™t think heâ€™ll ask us how they died? Get back on your horse.\n'],
#  ['WILL',
#   ' Whatever did it to them could do it to us. They even killed the children.\n'],
#  ['ROYCE',
#   ' Itâ€™s a good thing weâ€™re not children. You want to run away south, run away. Of course, they will behead you as a deserter â€¦ If I donâ€™t catch you first. Get back on your horse. I wonâ€™t say it again.\n'],
#  ['ROYCE', ' Your dead men seem to have moved camp.\n'],
#  ['WILL', ' They were here.\n'],
#  ['GARED', ' See where they went.\n'],
# ...

# %%
for i in range(0,len(c)):
    sent.append(c[i][1])

# %%
sent
# Out:
# [' Iâ€™ve never seen wildlings do a thing like this. Iâ€™ve never seen a thing like this, not ever in my life.\n',
#  ' How close did you get?\n',
#  ' Close as any man would.\n',
#  ' We should head back to the wall.\n',
#  ' Do the dead frighten you?\n',
#  ' Our orders were to track the wildlings. We tracked them. They wonâ€™t trouble us no more.\n',
#  ' You donâ€™t think heâ€™ll ask us how they died? Get back on your horse.\n',
#  ' Whatever did it to them could do it to us. They even killed the children.\n',
#  ' Itâ€™s a good thing weâ€™re not children. You want to run away south, run away. Of course, they will behead you as a deserter â€¦ If I donâ€™t catch you first. Get back on your horse. I wonâ€™t say it again.\n',
#  ' Your dead men seem to have moved camp.\n',
#  ' They were here.\n',
#  ' See where they went.\n',
#  ' What is it?\n',
#  ' Go on. Fatherâ€™s watching.\n',
#  ' And your mother.\n',
#  ' Fine work, as always. Well done.\n',
#  ' Thank you.\n',
# ...

# %%
for i in sent:
    i.replace("\n",'')
    i.replace("’ll"," will")
    i.replace("€™ve"," have")
    i.replace("’s"," is")
    i.replace("’m"," am")
    i.lower()

# %%
sent
# Out:
# [' Iâ€™ve never seen wildlings do a thing like this. Iâ€™ve never seen a thing like this, not ever in my life.\n',
#  ' How close did you get?\n',
#  ' Close as any man would.\n',
#  ' We should head back to the wall.\n',
#  ' Do the dead frighten you?\n',
#  ' Our orders were to track the wildlings. We tracked them. They wonâ€™t trouble us no more.\n',
#  ' You donâ€™t think heâ€™ll ask us how they died? Get back on your horse.\n',
#  ' Whatever did it to them could do it to us. They even killed the children.\n',
#  ' Itâ€™s a good thing weâ€™re not children. You want to run away south, run away. Of course, they will behead you as a deserter â€¦ If I donâ€™t catch you first. Get back on your horse. I wonâ€™t say it again.\n',
#  ' Your dead men seem to have moved camp.\n',
#  ' They were here.\n',
#  ' See where they went.\n',
#  ' What is it?\n',
#  ' Go on. Fatherâ€™s watching.\n',
#  ' And your mother.\n',
#  ' Fine work, as always. Well done.\n',
#  ' Thank you.\n',
# ...

# %%
for i in sent:
    d=i.replace("â€™ve"," have")
    e=d.lower()
    f=e.replace("\n","")
    g=f.replace("wonâ€™t"," would not")
    h=g.replace("donâ€™t "," do not")
    j=h.replace("â€™ll"," will")
    k=j.replace("â€™s "," is ")
    l=k.replace("€™re"," are")
    m=l.replace("wonâ€™t"," would not")
    n=m.replace("€™m"," am")
    new_sent.append(n)

# %%
new_sent
# Out:
# [' i have never seen wildlings do a thing like this. i have never seen a thing like this, not ever in my life.',
#  ' how close did you get?',
#  ' close as any man would.',
#  ' we should head back to the wall.',
#  ' do the dead frighten you?',
#  ' our orders were to track the wildlings. we tracked them. they  would not trouble us no more.',
#  ' you  do notthink he will ask us how they died? get back on your horse.',
#  ' whatever did it to them could do it to us. they even killed the children.',
#  ' it is a good thing weâ are not children. you want to run away south, run away. of course, they will behead you as a deserter â€¦ if i  do notcatch you first. get back on your horse. i  would not say it again.',
#  ' your dead men seem to have moved camp.',
#  ' they were here.',
#  ' see where they went.',
#  ' what is it?',
#  ' go on. father is watching.',
#  ' and your mother.',
#  ' fine work, as always. well done.',
#  ' thank you.',
# ...

# %%
c
# Out:
# [['WILL',
#   ' Iâ€™ve never seen wildlings do a thing like this. Iâ€™ve never seen a thing like this, not ever in my life.\n'],
#  ['WAYMAR ROYCE', ' How close did you get?\n'],
#  ['WILL', ' Close as any man would.\n'],
#  ['GARED', ' We should head back to the wall.\n'],
#  ['ROYCE', ' Do the dead frighten you?\n'],
#  ['GARED',
#   ' Our orders were to track the wildlings. We tracked them. They wonâ€™t trouble us no more.\n'],
#  ['ROYCE',
#   ' You donâ€™t think heâ€™ll ask us how they died? Get back on your horse.\n'],
#  ['WILL',
#   ' Whatever did it to them could do it to us. They even killed the children.\n'],
#  ['ROYCE',
#   ' Itâ€™s a good thing weâ€™re not children. You want to run away south, run away. Of course, they will behead you as a deserter â€¦ If I donâ€™t catch you first. Get back on your horse. I wonâ€™t say it again.\n'],
#  ['ROYCE', ' Your dead men seem to have moved camp.\n'],
#  ['WILL', ' They were here.\n'],
#  ['GARED', ' See where they went.\n'],
# ...

# %%
import pandas as pd
df=pd.DataFrame(c,columns=['Speaker','Sentence'])

# %%
df.tail(2)
# Out:
#     Speaker                                           Sentence
# 109  ROBERT   He never had to teach you much, but me â€¦ Yo...
# 110     NED                                             Aye.\n

# %%
df['Sentence']=df.groupby(['Speaker'])['Sentence'].transform(lambda x:' '.join(x))

# %%
df['Sentence']
# Out:
# 0       Iâ€™ve never seen wildlings do a thing like t...
# 1                               How close did you get?\n
# 2       Iâ€™ve never seen wildlings do a thing like t...
# 3       We should head back to the wall.\n  Our order...
# 4       Do the dead frighten you?\n  You donâ€™t thin...
#                              ...
# 106     And which one of you was a marksman at ten? K...
# 107     Youâ€™ve got fat.\n  Cat!\n  Nine years. Why ...
# 108     And which one of you was a marksman at ten? K...
# 109     Youâ€™ve got fat.\n  Cat!\n  Nine years. Why ...
# 110     And which one of you was a marksman at ten? K...
# Name: Sentence, Length: 111, dtype: object

# %%
df=df.drop_duplicates()

# %%
df.loc[0,'Sentence']
# Out:
# ' Iâ€™ve never seen wildlings do a thing like this. Iâ€™ve never seen a thing like this, not ever in my life.\n  Close as any man would.\n  Whatever did it to them could do it to us. They even killed the children.\n  They were here.\n'

# %%
df['Sentence']=df['Sentence'].str.lower()
# Out:
# <ipython-input-31-2327e0643bad>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Sentence']=df['Sentence'].str.lower()

# %%
x=df.reset_index(drop=True, inplace=True)

# %%
replace_values={'\n':'',"â€™ve":" have","wonâ€™t":" would not","donâ€™t": " do not","â€™ll":" will","â€™s":" is","€™re":" are","€™m":" am"}

# %%
df['Sentence'].replace('â€™ve'," have ")
# Out:
# 0      iâ€™ve never seen wildlings do a thing like t...
# 1                              how close did you get?\n
# 2      we should head back to the wall.\n  our order...
# 3      do the dead frighten you?\n  you donâ€™t thin...
# 4      go on. fatherâ€™s watching.\n  and your mothe...
# 5      fine work, as always. well done.\n  i love th...
# 6      thank you.\n  will you shut up?\n  would you ...
# 7      and which one of you was a marksman at ten? k...
# 8      relax your bow arm.\n  lad, go run back and g...
# 9      lord stark. my lady. a guardsman just rode in...
# 10     do you have to?\n  ned. ten is too young to s...
# 11     jon said he was a deserter.\n  our way is the...
# 12     mountain lion?\n  itâ€™s a freak.\n  right. g...
# 13     what if jon arryn told someone?\n  my husband...
# 14     but who would he tell?\n  if he told the king...
# 15     youâ€™ve got fat.\n  cat!\n  nine years. why ...
# 16     whereâ€™s the imp?\n  arya.\n  thatâ€™s jaime...
# ...

# %%
df
# Out:
#           Speaker                                           Sentence
# 0            WILL   iâ€™ve never seen wildlings do a thing like t...
# 1    WAYMAR ROYCE                           how close did you get?\n
# 2           GARED   we should head back to the wall.\n  our order...
# 3           ROYCE   do the dead frighten you?\n  you donâ€™t thin...
# 4             JON   go on. fatherâ€™s watching.\n  and your mothe...
# 5   SEPTA MORDANE   fine work, as always. well done.\n  i love th...
# 6           SANSA   thank you.\n  will you shut up?\n  would you ...
# 7             NED   and which one of you was a marksman at ten? k...
# 8            ROBB   relax your bow arm.\n  lad, go run back and g...
# 9          CASSEL   lord stark. my lady. a guardsman just rode in...
# 10        CATELYN   do you have to?\n  ned. ten is too young to s...
# 11           BRAN   jon said he was a deserter.\n  our way is the...
# 12          THEON   mountain lion?\n  itâ€™s a freak.\n  right. g...
# ...

# %%
dict=df.to_dict()

# %%
dict
# Out:
# {'Speaker': {0: 'WILL',
#   1: 'WAYMAR ROYCE',
#   2: 'GARED',
#   3: 'ROYCE',
#   4: 'JON',
#   5: 'SEPTA MORDANE',
#   6: 'SANSA',
#   7: 'NED',
#   8: 'ROBB',
#   9: 'CASSEL',
#   10: 'CATELYN',
#   11: 'BRAN',
#   12: 'THEON',
#   13: 'CERSEI',
#   14: 'JAIME',
#   15: 'ROBERT',
#   16: 'ARYA'},
#  'Sentence': {0: ' iâ€™ve never seen wildlings do a thing like this. iâ€™ve never seen a thing like this, not ever in my life.\n  close as any man would.\n  whatever did it to them could do it to us. they even killed the children.\n  they were here.\n',
#   1: ' how close did you get?\n',
#   2: ' we should head back to the wall.\n  our orders were to track the wildlings. we tracked them. they  would not  trouble us no more.\n  see where they went.\n',
# ...

# %%
df['Sentence']=df['Sentence'].str.replace("â€™ve"," have ")

# %%
df['Sentence']=df['Sentence'].str.replace("wonâ€™t"," would not ")

# %%
df['Sentence']=df['Sentence'].str.replace("donâ€™t"," do not ")

# %%
df['Sentence']=df['Sentence'].str.replace("â€™ll"," do not ")

# %%
 df['Sentence']=df['Sentence'].str.replace("â€™ll"," will ")

# %%
df['Sentence']=df['Sentence'].str.replace("â€™s"," is ")

# %%
 df['Sentence']=df['Sentence'].str.replace("€™re"," are ")

# %%
 df['Sentence']=df['Sentence'].str.replace("wonâ€™t"," would not ")

# %%
 df['Sentence']=df['Sentence'].str.replace("€™m"," am ")

# %%
for i in sent:
    d=i.replace("â€™ve"," have")
    e=d.lower()
    f=e.replace("\n","")
    g=f.replace("wonâ€™t"," would not")
    h=g.replace("donâ€™t "," do not")
    j=h.replace("â€™ll"," will")
    k=j.replace("â€™s "," is ")
    l=k.replace("€™re"," are")
    m=l.replace("wonâ€™t"," would not")
    n=m.replace("€™m"," am")
    new_sent.append(n)

# %%
df
# Out:
#           Speaker                                           Sentence
# 0            WILL   i have  never seen wildlings do a thing like ...
# 1    WAYMAR ROYCE                           how close did you get?\n
# 2           GARED   we should head back to the wall.\n  our order...
# 3           ROYCE   do the dead frighten you?\n  you  do not  thi...
# 4             JON   go on. father is  watching.\n  and your mothe...
# 5   SEPTA MORDANE   fine work, as always. well done.\n  i love th...
# 6           SANSA   thank you.\n  will you shut up?\n  would you ...
# 7             NED   and which one of you was a marksman at ten? k...
# 8            ROBB   relax your bow arm.\n  lad, go run back and g...
# 9          CASSEL   lord stark. my lady. a guardsman just rode in...
# 10        CATELYN   do you have to?\n  ned. ten is too young to s...
# 11           BRAN   jon said he was a deserter.\n  our way is the...
# 12          THEON   mountain lion?\n  it is  a freak.\n  right. g...
# ...

# %%
df['Sentence']=df['Sentence'].str.replace("\n"," ")

# %%
df
# Out:
#           Speaker                                           Sentence
# 0            WILL   i have  never seen wildlings do a thing like ...
# 1    WAYMAR ROYCE                            how close did you get?
# 2           GARED   we should head back to the wall.   our orders...
# 3           ROYCE   do the dead frighten you?   you  do not  thin...
# 4             JON   go on. father is  watching.   and your mother...
# 5   SEPTA MORDANE   fine work, as always. well done.   i love the...
# 6           SANSA   thank you.   will you shut up?   would you pl...
# 7             NED   and which one of you was a marksman at ten? k...
# 8            ROBB   relax your bow arm.   lad, go run back and ge...
# 9          CASSEL   lord stark. my lady. a guardsman just rode in...
# 10        CATELYN   do you have to?   ned. ten is too young to se...
# 11           BRAN   jon said he was a deserter.   our way is the ...
# 12          THEON   mountain lion?   it is  a freak.   right. giv...
# ...

# %%
df.loc[0,"Sentence"]
# Out:
# ' i have  never seen wildlings do a thing like this. i have  never seen a thing like this, not ever in my life.   close as any man would.   whatever did it to them could do it to us. they even killed the children.   they were here. '

# %%
df['Sentence']=df['Sentence'].str.strip()

# %%
df
# Out:
#           Speaker                                           Sentence
# 0            WILL  i have  never seen wildlings do a thing like t...
# 1    WAYMAR ROYCE                             how close did you get?
# 2           GARED  we should head back to the wall.   our orders ...
# 3           ROYCE  do the dead frighten you?   you  do not  think...
# 4             JON  go on. father is  watching.   and your mother....
# 5   SEPTA MORDANE  fine work, as always. well done.   i love the ...
# 6           SANSA  thank you.   will you shut up?   would you ple...
# 7             NED  and which one of you was a marksman at ten? ke...
# 8            ROBB  relax your bow arm.   lad, go run back and get...
# 9          CASSEL  lord stark. my lady. a guardsman just rode in ...
# 10        CATELYN  do you have to?   ned. ten is too young to see...
# 11           BRAN  jon said he was a deserter.   our way is the o...
# 12          THEON  mountain lion?   it is  a freak.   right. give...
# ...

# %%
df['Sentence'].str.replace(",","")
# Out:
# 0     i have  never seen wildlings do a thing like t...
# 1                                how close did you get?
# 2     we should head back to the wall.   our orders ...
# 3     do the dead frighten you?   you  do not  think...
# 4     go on. father is  watching.   and your mother....
# 5     fine work as always. well done.   i love the d...
# 6     thank you.   will you shut up?   would you ple...
# 7     and which one of you was a marksman at ten? ke...
# 8     relax your bow arm.   lad go run back and get ...
# 9     lord stark. my lady. a guardsman just rode in ...
# 10    do you have to?   ned. ten is too young to see...
# 11    jon said he was a deserter.   our way is the o...
# 12    mountain lion?   it is  a freak.   right. give...
# 13    what if jon arryn told someone?   my husband. ...
# 14    but who would he tell?   if he told the king b...
# 15    you have  got fat.   cat!   nine years. why ha...
# 16    where is  the imp?   arya.   that is  jaime la...
# ...

# %%
df
# Out:
#           Speaker                                           Sentence
# 0            WILL  i have  never seen wildlings do a thing like t...
# 1    WAYMAR ROYCE                             how close did you get?
# 2           GARED  we should head back to the wall.   our orders ...
# 3           ROYCE  do the dead frighten you?   you  do not  think...
# 4             JON  go on. father is  watching.   and your mother....
# 5   SEPTA MORDANE  fine work, as always. well done.   i love the ...
# 6           SANSA  thank you.   will you shut up?   would you ple...
# 7             NED  and which one of you was a marksman at ten? ke...
# 8            ROBB  relax your bow arm.   lad, go run back and get...
# 9          CASSEL  lord stark. my lady. a guardsman just rode in ...
# 10        CATELYN  do you have to?   ned. ten is too young to see...
# 11           BRAN  jon said he was a deserter.   our way is the o...
# 12          THEON  mountain lion?   it is  a freak.   right. give...
# ...

# %%
df
# Out:
#           Speaker                                           Sentence
# 0            WILL  i have  never seen wildlings do a thing like t...
# 1    WAYMAR ROYCE                             how close did you get?
# 2           GARED  we should head back to the wall.   our orders ...
# 3           ROYCE  do the dead frighten you?   you  do not  think...
# 4             JON  go on. father is  watching.   and your mother....
# 5   SEPTA MORDANE  fine work, as always. well done.   i love the ...
# 6           SANSA  thank you.   will you shut up?   would you ple...
# 7             NED  and which one of you was a marksman at ten? ke...
# 8            ROBB  relax your bow arm.   lad, go run back and get...
# 9          CASSEL  lord stark. my lady. a guardsman just rode in ...
# 10        CATELYN  do you have to?   ned. ten is too young to see...
# 11           BRAN  jon said he was a deserter.   our way is the o...
# 12          THEON  mountain lion?   it is  a freak.   right. give...
# ...

# %%
df['Sentence']=df['Sentence'].str.replace(".","")
# Out:
# <ipython-input-67-ee4610dcadc0>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df['Sentence']=df['Sentence'].str.replace(".","")

# %%
df['Sentence']=df['Sentence'].str.replace(",","")
df['Sentence']

# %%
df['Sentence']=df['Sentence'].str.replace("?","")
df['Sentence']=df['Sentence'].str.replace("?","")
df['Sentence']=df['Sentence'].str.replace("?","")
df['Sentence']=df['Sentence'].str.replace("?","")
# Out:
# <ipython-input-69-a373bf122ad0>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df['Sentence']=df['Sentence'].str.replace("?","")

# %%
df
# Out:
#           Speaker                                           Sentence
# 0            WILL  i have  never seen wildlings do a thing like t...
# 1    WAYMAR ROYCE                              how close did you get
# 2           GARED  we should head back to the wall   our orders w...
# 3           ROYCE  do the dead frighten you   you  do not  think ...
# 4             JON  go on father is  watching   and your mother   ...
# 5   SEPTA MORDANE  fine work as always well done   i love the det...
# 6           SANSA  thank you   will you shut up   would you pleas...
# 7             NED  and which one of you was a marksman at ten kee...
# 8            ROBB  relax your bow arm   lad go run back and get t...
# 9          CASSEL  lord stark my lady a guardsman just rode in fr...
# 10        CATELYN  do you have to   ned ten is too young to see s...
# 11           BRAN  jon said he was a deserter   our way is the ol...
# 12          THEON  mountain lion   it is  a freak   right give it...
# ...

# %%
df.loc[0,'Sentence']
# Out:
# 'i have  never seen wildlings do a thing like this i have  never seen a thing like this not ever in my life   close as any man would   whatever did it to them could do it to us they even killed the children   they were here'

# %%
df.loc[1,'Sentence']
# Out:
# 'how close did you get'

# %%
e=df.loc[0,'Sentence']

# %%
e
# Out:
# 'i have  never seen wildlings do a thing like this i have  never seen a thing like this not ever in my life   close as any man would   whatever did it to them could do it to us they even killed the children   they were here'

# %%
z=e.split(" ")
z[0]
# Out:
# 'i'

# %%
y=set(z)

# %%
df
# Out:
#           Speaker                                           Sentence
# 0            WILL  i have  never seen wildlings do a thing like t...
# 1    WAYMAR ROYCE                              how close did you get
# 2           GARED  we should head back to the wall   our orders w...
# 3           ROYCE  do the dead frighten you   you  do not  think ...
# 4             JON  go on father is  watching   and your mother   ...
# 5   SEPTA MORDANE  fine work as always well done   i love the det...
# 6           SANSA  thank you   will you shut up   would you pleas...
# 7             NED  and which one of you was a marksman at ten kee...
# 8            ROBB  relax your bow arm   lad go run back and get t...
# 9          CASSEL  lord stark my lady a guardsman just rode in fr...
# 10        CATELYN  do you have to   ned ten is too young to see s...
# 11           BRAN  jon said he was a deserter   our way is the ol...
# 12          THEON  mountain lion   it is  a freak   right give it...
# ...

# %%
y=df.loc[16,'Sentence']

# %%
x=y.split(" ")

# %%
x
# Out:
# ['where',
#  'is',
#  '',
#  'the',
#  'imp',
#  '',
#  '',
#  'arya',
#  '',
#  '',
#  'that',
#  'is',
#  '',
#  'jaime',
#  'lannister',
#  'the',
#  'queen',
#  'is',
#  '',
#  'twin',
#  'brother',
#  '',
#  '',
#  'where',
#  'is',
#  '',
#  'the',
#  'imp']

# %%
out=set(x)

# %%
out
# Out:
# {'',
#  'arya',
#  'brother',
#  'imp',
#  'is',
#  'jaime',
#  'lannister',
#  'queen',
#  'that',
#  'the',
#  'twin',
#  'where'}

# %%
seven=df.loc[7,'Sentence']

# %%
seven_out=seven.split(" ")

# %%
sevenout=set(seven_out)

# %%
sevenout
# Out:
# {'',
#  'a',
#  'about',
#  'all',
#  'am',
#  'an',
#  'and',
#  'andals',
#  'are',
#  'arryn',
#  'at',
#  'aye',
#  'be',
#  'beast',
#  'been',
#  'better',
#  'both',
#  'boy',
#  'bran',
#  'bury',
#  'but',
#  'cat',
#  'children',
#  'coming',
#  'death',
#  'did',
#  'die',
#  'direwolf',
#  'do',
#  'eddard',
#  'feed',
#  'first',
#  'five',
#  'for',
#  'forever',
#  'get',
#  'go',
#  'gods',
#  'gone',
#  'grace',
#  'guarding',
#  'had',
#  'have',
#  'he',
#  'him',
#  'horses',
#  'house',
#  'i',
#  'if',
#  'in',
#  'is',
#  'it',
#  'iâ',
#  'jon',
#  'keep',
#  'kill',
#  'king',
#  'kingdoms',
#  'lads',
#  'last',
#  'lions',
#  'lord',
#  'madman',
#  'man',
#  'marksman',
#  'me',
#  'men',
#  'mother',
#  'mountain',
#  'my',
#  'no',
#  'north',
#  'northern',
#  'not',
#  'oath',
#  'of',
#  'old',
#  'on',
#  'one',
#  'outsider',
#  'passes',
#  'practicing',
#  'protector',
#  'queen',
#  'quick',
#  'realm',
#  'rules',
#  'saddle',
#  'sees',
# ...

# %%
list=[]
list.append(df['Sentence'])
main_list=[]

# %%
for i in df['Sentence']:
    s=i.split(" ")
    main_list.append(s)

# %%
list
# Out:
# [0     i have  never seen wildlings do a thing like t...
#  1                                 how close did you get
#  2     we should head back to the wall   our orders w...
#  3     do the dead frighten you   you  do not  think ...
#  4     go on father is  watching   and your mother   ...
#  5     fine work as always well done   i love the det...
#  6     thank you   will you shut up   would you pleas...
#  7     and which one of you was a marksman at ten kee...
#  8     relax your bow arm   lad go run back and get t...
#  9     lord stark my lady a guardsman just rode in fr...
#  10    do you have to   ned ten is too young to see s...
#  11    jon said he was a deserter   our way is the ol...
#  12    mountain lion   it is  a freak   right give it...
#  13    what if jon arryn told someone   my husband   ...
#  14    but who would he tell   if he told the king bo...
#  15    you have  got fat   cat!   nine years why have...
# ...

# %%
unique_list=[]
main_list
for i in main_list:
    print(set(i))
    unique_list.append(set(i))
# Out:
# {'', 'killed', 'like', 'close', 'the', 'them', 'life', 'did', 'were', 'would', 'whatever', 'thing', 'a', 'children', 'to', 'man', 'never', 'in', 'any', 'they', 'i', 'not', 'even', 'have', 'wildlings', 'as', 'us', 'could', 'this', 'it', 'ever', 'here', 'seen', 'my', 'do'}
# {'did', 'get', 'close', 'how', 'you'}
# {'', 'head', 'back', 'track', 'the', 'see', 'them', 'orders', 'wall', 'were', 'would', 'trouble', 'we', 'where', 'to', 'no', 'more', 'tracked', 'they', 'went', 'not', 'wildlings', 'should', 'us', 'our'}
# {'', 'if', 'horse', 'deserter', 'back', 'do', 'again', 'behead', 'the', 'think', 'south', 'frighten', 'course', 'how', 'are', 'would', 'thing', 'a', 'children', 'camp', 'on', 'you', 'to', 'first', 'run', 'ask', 'â€¦', 'he', 'good', 'men', 'they', 'dead', 'i', 'not', 'have', 'want', 'will', 'catch', 'get', 'as', 'moved', 'us', 'away', 'it', 'seem', 'what', 'died', 'of', 'weâ', 'is', 'say', 'your'}
# ...

# %%
unique_list
# Out:
# [{'',
#   'a',
#   'any',
#   'as',
#   'children',
#   'close',
#   'could',
#   'did',
#   'do',
#   'even',
#   'ever',
#   'have',
#   'here',
#   'i',
#   'in',
#   'it',
#   'killed',
#   'life',
#   'like',
#   'man',
#   'my',
#   'never',
#   'not',
#   'seen',
#   'the',
#   'them',
#   'they',
#   'thing',
#   'this',
#   'to',
#   'us',
#   'were',
#   'whatever',
#   'wildlings',
#   'would'},
#  {'close', 'did', 'get', 'how', 'you'},
#  {'',
#   'back',
#   'head',
#   'more',
#   'no',
#   'not',
#   'orders',
#   'our',
#   'see',
#   'should',
#   'the',
#   'them',
#   'they',
#   'to',
#   'track',
#   'tracked',
#   'trouble',
#   'us',
#   'wall',
#   'we',
#   'went',
#   'were',
#   'where',
#   'wildlings',
#   'would'},
#  {'',
#   'a',
#   'again',
#   'are',
#   'as',
#   'ask',
#   'away',
#   'back',
#   'behead',
#   'camp',
#   'catch',
#   'children',
#   'course',
#   'dead',
#   'deserter',
#   'died',
#   'do',
#   'first',
#   'frighten',
# ...

# %%
df['Unique Words']=unique_list

# %%
df.loc[0,'Unique Words']
# Out:
# {'',
#  'a',
#  'any',
#  'as',
#  'children',
#  'close',
#  'could',
#  'did',
#  'do',
#  'even',
#  'ever',
#  'have',
#  'here',
#  'i',
#  'in',
#  'it',
#  'killed',
#  'life',
#  'like',
#  'man',
#  'my',
#  'never',
#  'not',
#  'seen',
#  'the',
#  'them',
#  'they',
#  'thing',
#  'this',
#  'to',
#  'us',
#  'were',
#  'whatever',
#  'wildlings',
#  'would'}

# %%
df.loc[8,'Unique Words']
# Out:
# {'',
#  'a',
#  'and',
#  'are',
#  'arm',
#  'away',
#  'back',
#  'better',
#  'blade',
#  'bow',
#  'direwolves',
#  'get',
#  'girl',
#  'go',
#  'good',
#  'hair',
#  'he',
#  'hear',
#  'him',
#  'his',
#  'i',
#  'is',
#  'it',
#  'lad',
#  'likes',
#  'met',
#  'never',
#  'no',
#  'of',
#  'on',
#  'own',
#  'prick',
#  'prince',
#  'put',
#  'relax',
#  'rest',
#  'right',
#  'royal',
#  'run',
#  'shave',
#  'south',
#  'than',
#  'the',
#  'there',
#  'tommy',
#  'wall',
#  'what',
#  'your'}

# %%
df
# Out:
#           Speaker                                           Sentence  \
# 0            WILL  i have  never seen wildlings do a thing like t...
# 1    WAYMAR ROYCE                              how close did you get
# 2           GARED  we should head back to the wall   our orders w...
# 3           ROYCE  do the dead frighten you   you  do not  think ...
# 4             JON  go on father is  watching   and your mother   ...
# 5   SEPTA MORDANE  fine work as always well done   i love the det...
# 6           SANSA  thank you   will you shut up   would you pleas...
# 7             NED  and which one of you was a marksman at ten kee...
# 8            ROBB  relax your bow arm   lad go run back and get t...
# 9          CASSEL  lord stark my lady a guardsman just rode in fr...
# 10        CATELYN  do you have to   ned ten is too young to see s...
# 11           BRAN  jon said he was a deserter   our way is the ol...
# 12          THEON  mountain lion   it is  a freak   right give it...
# ...

# %%
df.loc[0,'Sentence']
# Out:
# 'i have  never seen wildlings do a thing like this i have  never seen a thing like this not ever in my life   close as any man would   whatever did it to them could do it to us they even killed the children   they were here'

# %%
df.loc[0,'Unique Words']
# Out:
# {'',
#  'a',
#  'any',
#  'as',
#  'children',
#  'close',
#  'could',
#  'did',
#  'do',
#  'even',
#  'ever',
#  'have',
#  'here',
#  'i',
#  'in',
#  'it',
#  'killed',
#  'life',
#  'like',
#  'man',
#  'my',
#  'never',
#  'not',
#  'seen',
#  'the',
#  'them',
#  'they',
#  'thing',
#  'this',
#  'to',
#  'us',
#  'were',
#  'whatever',
#  'wildlings',
#  'would'}

# %%
print(j[0])
# Out:
# i

# %%
for i in df['Speaker']:
    print(i)
# Out:
# WILL
# WAYMAR ROYCE
# GARED
# ROYCE
# JON
# SEPTA MORDANE
# SANSA
# NED
# ROBB
# CASSEL
# CATELYN
# BRAN
# THEON
# CERSEI
# JAIME
# ROBERT
# ARYA

# %%
df.loc[8,'Unique Words']
# Out:
# {'',
#  'a',
#  'and',
#  'are',
#  'arm',
#  'away',
#  'back',
#  'better',
#  'blade',
#  'bow',
#  'direwolves',
#  'get',
#  'girl',
#  'go',
#  'good',
#  'hair',
#  'he',
#  'hear',
#  'him',
#  'his',
#  'i',
#  'is',
#  'it',
#  'lad',
#  'likes',
#  'met',
#  'never',
#  'no',
#  'of',
#  'on',
#  'own',
#  'prick',
#  'prince',
#  'put',
#  'relax',
#  'rest',
#  'right',
#  'royal',
#  'run',
#  'shave',
#  'south',
#  'than',
#  'the',
#  'there',
#  'tommy',
#  'wall',
#  'what',
#  'your'}

# %%
for i in df['Speaker']:
    for j in df['Unique Words']:
        print(j)
# Out:
# {'', 'killed', 'like', 'close', 'the', 'them', 'life', 'did', 'were', 'would', 'whatever', 'thing', 'a', 'children', 'to', 'man', 'never', 'in', 'any', 'they', 'i', 'not', 'even', 'have', 'wildlings', 'as', 'us', 'could', 'this', 'it', 'ever', 'here', 'seen', 'my', 'do'}
# {'did', 'get', 'close', 'how', 'you'}
# {'', 'head', 'back', 'track', 'the', 'see', 'them', 'orders', 'wall', 'were', 'would', 'trouble', 'we', 'where', 'to', 'no', 'more', 'tracked', 'they', 'went', 'not', 'wildlings', 'should', 'us', 'our'}
# {'', 'if', 'horse', 'deserter', 'back', 'do', 'again', 'behead', 'the', 'think', 'south', 'frighten', 'course', 'how', 'are', 'would', 'thing', 'a', 'children', 'camp', 'on', 'you', 'to', 'first', 'run', 'ask', 'â€¦', 'he', 'good', 'men', 'they', 'dead', 'i', 'not', 'have', 'want', 'will', 'catch', 'get', 'as', 'moved', 'us', 'away', 'it', 'seem', 'what', 'died', 'of', 'weâ', 'is', 'say', 'your'}
# ...

# %%
speaker=[]
for i in df['Speaker']:
    speaker.append(i)
speaker
# Out:
# ['WILL',
#  'WAYMAR ROYCE',
#  'GARED',
#  'ROYCE',
#  'JON',
#  'SEPTA MORDANE',
#  'SANSA',
#  'NED',
#  'ROBB',
#  'CASSEL',
#  'CATELYN',
#  'BRAN',
#  'THEON',
#  'CERSEI',
#  'JAIME',
#  'ROBERT',
#  'ARYA']

# %%
filename=[]
for i in speaker:
    filename.append(i+'.txt')

# %%
filename
# Out:
# ['WILL.txt',
#  'WAYMAR ROYCE.txt',
#  'GARED.txt',
#  'ROYCE.txt',
#  'JON.txt',
#  'SEPTA MORDANE.txt',
#  'SANSA.txt',
#  'NED.txt',
#  'ROBB.txt',
#  'CASSEL.txt',
#  'CATELYN.txt',
#  'BRAN.txt',
#  'THEON.txt',
#  'CERSEI.txt',
#  'JAIME.txt',
#  'ROBERT.txt',
#  'ARYA.txt']

# %%
#Creating new text files for the unique characters
for i in filename:
    open(i,'w')

# %%
open('Unique Speakers.txt','w')
# Out:
# <_io.TextIOWrapper name='Unique Speakers.txt' mode='w' encoding='cp1252'>

# %%
for i in filename:
    open(i,'w')

# %%
df
# Out:
#           Speaker                                           Sentence  \
# 0            WILL  i have  never seen wildlings do a thing like t...
# 1    WAYMAR ROYCE                              how close did you get
# 2           GARED  we should head back to the wall   our orders w...
# 3           ROYCE  do the dead frighten you   you  do not  think ...
# 4             JON  go on father is  watching   and your mother   ...
# 5   SEPTA MORDANE  fine work as always well done   i love the det...
# 6           SANSA  thank you   will you shut up   would you pleas...
# 7             NED  and which one of you was a marksman at ten kee...
# 8            ROBB  relax your bow arm   lad go run back and get t...
# 9          CASSEL  lord stark my lady a guardsman just rode in fr...
# 10        CATELYN  do you have to   ned ten is too young to see s...
# 11           BRAN  jon said he was a deserter   our way is the ol...
# 12          THEON  mountain lion   it is  a freak   right give it...
# ...

# %%
practice=open('abc.txt','w')


for i in df.loc[0,'Unique Words']:
    print(i)
# Out:
# killed
# like
# close
# the
# them
# life
# did
# were
# would
# whatever
# thing
# a
# children
# to
# man
# never
# in
# any
# they
# i
# not
# even
# have
# wildlings
# as
# us
# could
# this
# it
# ever
# here
# seen
# my
# do

# %%
unique_list=df['Unique Words'].values.tolist()

# %%
unique_list
# Out:
# [{'',
#   'a',
#   'any',
#   'as',
#   'children',
#   'close',
#   'could',
#   'did',
#   'do',
#   'even',
#   'ever',
#   'have',
#   'here',
#   'i',
#   'in',
#   'it',
#   'killed',
#   'life',
#   'like',
#   'man',
#   'my',
#   'never',
#   'not',
#   'seen',
#   'the',
#   'them',
#   'they',
#   'thing',
#   'this',
#   'to',
#   'us',
#   'were',
#   'whatever',
#   'wildlings',
#   'would'},
#  {'close', 'did', 'get', 'how', 'you'},
#  {'',
#   'back',
#   'head',
#   'more',
#   'no',
#   'not',
#   'orders',
#   'our',
#   'see',
#   'should',
#   'the',
#   'them',
#   'they',
#   'to',
#   'track',
#   'tracked',
#   'trouble',
#   'us',
#   'wall',
#   'we',
#   'went',
#   'were',
#   'where',
#   'wildlings',
#   'would'},
#  {'',
#   'a',
#   'again',
#   'are',
#   'as',
#   'ask',
#   'away',
#   'back',
#   'behead',
#   'camp',
#   'catch',
#   'children',
#   'course',
#   'dead',
#   'deserter',
#   'died',
#   'do',
#   'first',
#   'frighten',
# ...

# %%
filenamemod=[]
for i in filename:
    filenamemod.append(i+'\n')

# %%
filenamemod
# Out:
# ['WILL.txt\n',
#  'WAYMAR ROYCE.txt\n',
#  'GARED.txt\n',
#  'ROYCE.txt\n',
#  'JON.txt\n',
#  'SEPTA MORDANE.txt\n',
#  'SANSA.txt\n',
#  'NED.txt\n',
#  'ROBB.txt\n',
#  'CASSEL.txt\n',
#  'CATELYN.txt\n',
#  'BRAN.txt\n',
#  'THEON.txt\n',
#  'CERSEI.txt\n',
#  'JAIME.txt\n',
#  'ROBERT.txt\n',
#  'ARYA.txt\n']

# %%
df.loc[7,'Unique Words']
# Out:
# {'',
#  'a',
#  'about',
#  'all',
#  'am',
#  'an',
#  'and',
#  'andals',
#  'are',
#  'arryn',
#  'at',
#  'aye',
#  'be',
#  'beast',
#  'been',
#  'better',
#  'both',
#  'boy',
#  'bran',
#  'bury',
#  'but',
#  'cat',
#  'children',
#  'coming',
#  'death',
#  'did',
#  'die',
#  'direwolf',
#  'do',
#  'eddard',
#  'feed',
#  'first',
#  'five',
#  'for',
#  'forever',
#  'get',
#  'go',
#  'gods',
#  'gone',
#  'grace',
#  'guarding',
#  'had',
#  'have',
#  'he',
#  'him',
#  'horses',
#  'house',
#  'i',
#  'if',
#  'in',
#  'is',
#  'it',
#  'iâ',
#  'jon',
#  'keep',
#  'kill',
#  'king',
#  'kingdoms',
#  'lads',
#  'last',
#  'lions',
#  'lord',
#  'madman',
#  'man',
#  'marksman',
#  'me',
#  'men',
#  'mother',
#  'mountain',
#  'my',
#  'no',
#  'north',
#  'northern',
#  'not',
#  'oath',
#  'of',
#  'old',
#  'on',
#  'one',
#  'outsider',
#  'passes',
#  'practicing',
#  'protector',
#  'queen',
#  'quick',
#  'realm',
#  'rules',
#  'saddle',
#  'sees',
# ...

# %%
df.loc[3,'Sentence']
# Out:
# 'do the dead frighten you   you  do not  think he do not  ask us how they died get back on your horse   it is  a good thing weâ are  not children you want to run away south run away of course they will behead you as a deserter â€¦ if i  do not  catch you first get back on your horse i  would not  say it again   your dead men seem to have moved camp   what is it'

# %%
for i in df['Unique Words']:
    list(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-127-1161405def59> in <module>
#       1 for i in df['Unique Words']:
# ----> 2     list(i)
#
# TypeError: 'list' object is not callable

# %%
df
# Out:
#           Speaker                                           Sentence  \
# 0            WILL  i have  never seen wildlings do a thing like t...
# 1    WAYMAR ROYCE                              how close did you get
# 2           GARED  we should head back to the wall   our orders w...
# 3           ROYCE  do the dead frighten you   you  do not  think ...
# 4             JON  go on father is  watching   and your mother   ...
# 5   SEPTA MORDANE  fine work as always well done   i love the det...
# 6           SANSA  thank you   will you shut up   would you pleas...
# 7             NED  and which one of you was a marksman at ten kee...
# 8            ROBB  relax your bow arm   lad go run back and get t...
# 9          CASSEL  lord stark my lady a guardsman just rode in fr...
# 10        CATELYN  do you have to   ned ten is too young to see s...
# 11           BRAN  jon said he was a deserter   our way is the ol...
# 12          THEON  mountain lion   it is  a freak   right give it...
# ...

# %%
df.loc[0,'Unique Words']
# Out:
# {'',
#  'a',
#  'any',
#  'as',
#  'children',
#  'close',
#  'could',
#  'did',
#  'do',
#  'even',
#  'ever',
#  'have',
#  'here',
#  'i',
#  'in',
#  'it',
#  'killed',
#  'life',
#  'like',
#  'man',
#  'my',
#  'never',
#  'not',
#  'seen',
#  'the',
#  'them',
#  'they',
#  'thing',
#  'this',
#  'to',
#  'us',
#  'were',
#  'whatever',
#  'wildlings',
#  'would'}

# %%
for i in df['Speaker']:
    for j in df['Unique Words']:
        for k in j:
            print(k)
# Out:
# killed
# like
# close
# the
# them
# life
# did
# were
# would
# whatever
# thing
# a
# children
# to
# man
# never
# in
# any
# they
# i
# not
# even
# have
# wildlings
# as
# us
# could
# this
# it
# ever
# here
# seen
# my
# do
# did
# get
# close
# how
# you
#
# head
# back
# track
# the
# see
# them
# orders
# wall
# were
# would
# trouble
# we
# where
# to
# no
# more
# tracked
# they
# went
# not
# wildlings
# should
# us
# our
#
# if
# horse
# deserter
# back
# do
# again
# behead
# the
# think
# south
# frighten
# course
# how
# are
# would
# thing
# a
# children
# camp
# on
# you
# to
# first
# run
# ask
# â€¦
# he
# good
# men
# they
# dead
# i
# not
# have
# want
# will
# catch
# get
# as
# moved
# us
# away
# it
# seem
# what
# died
# of
# weâ
# is
# say
# your
#
# and
# if
# your
# think
# the
# mother
# them
# well
# father
# did
# are
# too
# much
# were
# pups
# go
# watching
# stark
# one
# children
# know
# there
# a
# bran
# you
# on
# to
# now
# sigil
# direwolf
# ...

# %%
df.set_index('Speaker').T.to_dict('list')

# %%
df

# %%
df_mod=df.drop('Sentence',axis=1)

# %%
open
# Out:
# <function io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>

# %%
speaker
# Out:
# ['WILL',
#  'WAYMAR ROYCE',
#  'GARED',
#  'ROYCE',
#  'JON',
#  'SEPTA MORDANE',
#  'SANSA',
#  'NED',
#  'ROBB',
#  'CASSEL',
#  'CATELYN',
#  'BRAN',
#  'THEON',
#  'CERSEI',
#  'JAIME',
#  'ROBERT',
#  'ARYA']

# %%
df
# Out:
#           Speaker                                           Sentence  \
# 0            WILL  i have  never seen wildlings do a thing like t...
# 1    WAYMAR ROYCE                              how close did you get
# 2           GARED  we should head back to the wall   our orders w...
# 3           ROYCE  do the dead frighten you   you  do not  think ...
# 4             JON  go on father is  watching   and your mother   ...
# 5   SEPTA MORDANE  fine work as always well done   i love the det...
# 6           SANSA  thank you   will you shut up   would you pleas...
# 7             NED  and which one of you was a marksman at ten kee...
# 8            ROBB  relax your bow arm   lad go run back and get t...
# 9          CASSEL  lord stark my lady a guardsman just rode in fr...
# 10        CATELYN  do you have to   ned ten is too young to see s...
# 11           BRAN  jon said he was a deserter   our way is the ol...
# 12          THEON  mountain lion   it is  a freak   right give it...
# ...

# %%
speaker
# Out:
# ['WILL',
#  'WAYMAR ROYCE',
#  'GARED',
#  'ROYCE',
#  'JON',
#  'SEPTA MORDANE',
#  'SANSA',
#  'NED',
#  'ROBB',
#  'CASSEL',
#  'CATELYN',
#  'BRAN',
#  'THEON',
#  'CERSEI',
#  'JAIME',
#  'ROBERT',
#  'ARYA']

# %%
df
# Out:
#           Speaker                                           Sentence  \
# 0            WILL  i have  never seen wildlings do a thing like t...
# 1    WAYMAR ROYCE                              how close did you get
# 2           GARED  we should head back to the wall   our orders w...
# 3           ROYCE  do the dead frighten you   you  do not  think ...
# 4             JON  go on father is  watching   and your mother   ...
# 5   SEPTA MORDANE  fine work as always well done   i love the det...
# 6           SANSA  thank you   will you shut up   would you pleas...
# 7             NED  and which one of you was a marksman at ten kee...
# 8            ROBB  relax your bow arm   lad go run back and get t...
# 9          CASSEL  lord stark my lady a guardsman just rode in fr...
# 10        CATELYN  do you have to   ned ten is too young to see s...
# 11           BRAN  jon said he was a deserter   our way is the ol...
# 12          THEON  mountain lion   it is  a freak   right give it...
# ...

# %%
speaker_mod=[]
for i in speaker:
    speaker_mod.append(i+'\n')
    speaker_mod[0]=

# %%
#speaker_mod

# %%
#writing the names of unique speakers inside the unique speakers.txt file
speaker_txt=open('Unique Speakers.txt','w')
speaker_txt.writelines(speaker_mod)
speaker_txt.close()

# %%
master_list=[]
for i in df['Unique Words']:
    master_list.append(i)

# %%
master_list
df
# Out:
#           Speaker                                           Sentence  \
# 0            WILL  i have  never seen wildlings do a thing like t...
# 1    WAYMAR ROYCE                              how close did you get
# 2           GARED  we should head back to the wall   our orders w...
# 3           ROYCE  do the dead frighten you   you  do not  think ...
# 4             JON  go on father is  watching   and your mother   ...
# 5   SEPTA MORDANE  fine work as always well done   i love the det...
# 6           SANSA  thank you   will you shut up   would you pleas...
# 7             NED  and which one of you was a marksman at ten kee...
# 8            ROBB  relax your bow arm   lad go run back and get t...
# 9          CASSEL  lord stark my lady a guardsman just rode in fr...
# 10        CATELYN  do you have to   ned ten is too young to see s...
# 11           BRAN  jon said he was a deserter   our way is the ol...
# 12          THEON  mountain lion   it is  a freak   right give it...
# ...

# %%
#converting the set of  unique words into a dataframe
will=[]
waymar=[]
gared=[]
royce=[]
jon=[]
septa=[]
sansa=[]
ned=[]
robb=[]
cassel=[]
catelyn=[]
bran=[]
theon=[]
cersei=[]
jaime=[]
robert=[]
arya=[]
for i in df.loc[0,'Unique Words']:
    will.append(i+'\n')
for i in df.loc[1,'Unique Words']:
    waymar.append(i+'\n')
for i in df.loc[2,'Unique Words']:
    gared.append(i+'\n')
for i in df.loc[3,'Unique Words']:
    royce.append(i+'\n')
    for j in royce:
        j.replace("€¦","")
for i in df.loc[4,'Unique Words']:
    jon.append(i+'\n')
    for j in jon:
        j.replace("â","")
for i in df.loc[5,'Unique Words']:
    septa.append(i+'\n')
for i in df.loc[6,'Unique Words']:
    sansa.append(i+'\n')
for i in df.loc[7,'Unique Words']:
    ned.append(i+'\n')
    for j in ned:
        j.replace("â","")
for i in df.loc[8,'Unique Words']:
    robb.append(i+'\n')
for i in df.loc[9,'Unique Words']:
    cassel.append(i+'\n')
for i in df.loc[10,'Unique Words']:
    catelyn.append(i+'\n')
for i in df.loc[11,'Unique Words']:
    bran.append(i+'\n')
for i in df.loc[12,'Unique Words']:
    theon.append(i+'\n')
for i in df.loc[13,'Unique Words']:
    cersei.append(i+'\n')
for i in df.loc[14,'Unique Words']:
    jaime.append(i+'\n')
for i in df.loc[15,'Unique Words']:
    robert.append(i+'\n')
for i in df.loc[16,'Unique Words']:
    arya.append(i+'\n')

# %%
#writing the unique characters in multiple text files
f=open('WILL.txt','w')
f.writelines(will)
f.close()
f=open('WAYMAR ROYCE.txt','w')
f.writelines(waymar)
f.close()
f=open('GARED.txt','w')
f.writelines(gared)
f.close()
f=open('ROYCE.txt','w')
f.writelines(royce)
f.close()
f=open('JON.txt','w')
f.writelines(jon)
f.close()
f=open('SEPTA MORDANE.txt','w')
f.writelines(septa)
f.close()
f=open('SANSA.txt','w')
f.writelines(sansa)
f.close()
f=open('NED.txt','w')
f.writelines(ned)
f.close()
f=open('ROBB.txt','w')
f.writelines(robb)
f.close()
f=open('CASSEL.txt','w')
f.writelines(cassel)
f.close()
f=open('CATELYN.txt','w')
f.writelines(catelyn)
f.close()
f=open('BRAN.txt','w')
f.writelines(bran)
f.close()
f=open('THEON.txt','w')
f.writelines(theon)
f.close()
f=open('CERSEI.txt','w')
f.writelines(cersei)
f.close()
f=open('JAIME.txt','w')
f.writelines(jaime)
f.close()
f=open('ROBERT.txt','w')
f.writelines(robert)
f.close()
f=open('ARYA.txt','w')
f.writelines(arya)
f.close()

# %%
will
# Out:
# ['\n',
#  'killed\n',
#  'like\n',
#  'close\n',
#  'the\n',
#  'them\n',
#  'life\n',
#  'did\n',
#  'were\n',
#  'would\n',
#  'whatever\n',
#  'thing\n',
#  'a\n',
#  'children\n',
#  'to\n',
#  'man\n',
#  'never\n',
#  'in\n',
#  'any\n',
#  'they\n',
#  'i\n',
#  'not\n',
#  'even\n',
#  'have\n',
#  'wildlings\n',
#  'as\n',
#  'us\n',
#  'could\n',
#  'this\n',
#  'it\n',
#  'ever\n',
#  'here\n',
#  'seen\n',
#  'my\n',
#  'do\n']

# %%
filename
# Out:
# ['WILL.txt',
#  'WAYMAR ROYCE.txt',
#  'GARED.txt',
#  'ROYCE.txt',
#  'JON.txt',
#  'SEPTA MORDANE.txt',
#  'SANSA.txt',
#  'NED.txt',
#  'ROBB.txt',
#  'CASSEL.txt',
#  'CATELYN.txt',
#  'BRAN.txt',
#  'THEON.txt',
#  'CERSEI.txt',
#  'JAIME.txt',
#  'ROBERT.txt',
#  'ARYA.txt']

# %%
df.loc[16,'Unique Words']
# Out:
# {'',
#  'arya',
#  'brother',
#  'imp',
#  'is',
#  'jaime',
#  'lannister',
#  'queen',
#  'that',
#  'the',
#  'twin',
#  'where'}

# %%
f=open('ROYCE.txt','w')
f.writelines(royce)
f.close()
